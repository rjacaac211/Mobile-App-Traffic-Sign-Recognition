# %%
# !nvidia-smi
# Out:
# Mon Aug 26 22:25:24 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.65                 Driver Version: 546.65       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1660 ...  WDDM  | 00000000:01:00.0  On |                  N/A |
# | 29%   36C    P8              N/A /  N/A |    698MiB /  6144MiB |      3%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# d:\Users\RJ\Projects\Thesis\TSR_detection

# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.81  Python-3.10.12 torch-2.4.0+cpu CPU (Intel Core(TM) i5-9400F 2.90GHz)
# Setup complete  (6 CPUs, 11.9 GB RAM, 496.1/931.5 GB disk)

# %%
# Load the trained model
model = YOLO('runs/detect/tsd_model_7/weights/best0.pt')

# Convert to tfLite with int8 quantization
model.export(format='tflite', int8=True, data='../../data/Detection/Traffic-Sign-Detection-17/data.yaml')
